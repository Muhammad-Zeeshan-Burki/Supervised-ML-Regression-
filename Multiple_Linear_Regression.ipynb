# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("data.csv")
dataset.head(5)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
dataset.shape
# Out:
# (169, 4)

# %%
dataset.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
dataset["Calories"] =dataset["Calories"].fillna(dataset["Calories"].mean())

# %%
sns.pairplot(data=dataset)
plt.show()

# %%
sns.heatmap(data=dataset.corr(),annot=True)
plt.show()

# %%
x= dataset.iloc[:,:-1]
y=dataset["Calories"]

# %%
dataset.shape
# Out:
# (169, 4)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test ,y_train ,y_test =train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.8719156694442866

# %%
#y =m1x1+m2x2+m3x3+c

# %%
lr.coef_
# Out:
# array([5.31656646, 0.33747623, 1.94672802])

# %%
lr.intercept_
# Out:
# -265.15209393502204

# %%
x.columns
# Out:
# Index(['Duration', 'Pulse', 'Maxpulse'], dtype='object')

# %%
#Y =5.31656646*'Duration'+0.33747623*'Pulse'+1.94672802*'Maxpulse'+-265.15209393502204

# %%
lr.predict(x_test)
# Out:
# array([ 280.87667864,  308.76343012,  329.9962209 ,  339.39238479,
#         305.32797301,  259.22828224,  373.23984305,  485.90509137,
#         174.91137678, 1199.25078036,  320.52192764,  321.19688011,
#         346.5824738 ,  318.91267585,  141.70672739,  276.24757535,
#         333.55220072, 1255.75906372,  489.75256164,  477.31911165,
#         250.16959459,  321.19688011,  222.49979663,  328.04949288,
#         338.7955617 ,  328.30883974,  199.70014739,  186.15118059,
#         270.38995667,  378.89880964,  325.09033615,  329.21818033,
#         270.06991504,  251.5976289 ])
